# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Step 1. Go to Dataset Link
# https://www.kaggle.com/zhangjuefei/birds-bones-and-living-habits
#
# ## Step 2. Download the dataset to your computer and unzip it
# ## Step 3. Use the Csv file and assign it to a dataframe called birds
# - dataframe = birds
# - df = birds

# %%
import pandas as pd

# %%
birds = pd.read_csv('bird.csv')
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %% [markdown]
# ## Step 4. See the random 5 entries¶

# %%
birds.sample(5)
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 70    70   26.63   1.63   27.19   1.72  12.21  1.02   31.56  1.07  21.62
# 57    57  250.00  11.91  252.00   8.31  73.04  7.37  160.00  8.47  82.46
# 328  328   27.06   2.50   30.28   2.10  23.96  2.24   46.02  1.76  33.91
# 171  171   22.89   1.55   24.62   1.59  15.71  1.14   34.27  1.06  21.02
# 333  333   20.80   1.95   23.44   1.60  20.67  1.45   35.52  1.45  25.41
#
#      tarw type
# 70   0.83   SW
# 57   7.04   SW
# 328  1.76   SO
# 171  1.04    W
# 333  1.36   SO

# %% [markdown]
# ## Step 5. What is the number of observations in the dataset?

# %%
birds.count()
# Out:
# id       420
# huml     419
# humw     419
# ulnal    417
# ulnaw    418
# feml     418
# femw     419
# tibl     418
# tibw     419
# tarl     419
# tarw     419
# type     420
# dtype: int64

# %% [markdown]
# ## Step 6. What is the number of columns in the dataset?

# %%
len(birds.columns)
# Out:
# 12

# %%
len(birds) #rows
# Out:
# 420

# %% [markdown]
# ## Step 7. Print the name of all the columns¶

# %%
birds.columns
# Out:
# Index(['id', 'huml', 'humw', 'ulnal', 'ulnaw', 'feml', 'femw', 'tibl', 'tibw',
#        'tarl', 'tarw', 'type'],
#       dtype='object')

# %% [markdown]
# ## Step 8. What is the name of 10th column?

# %%
position = 10
colname = birds.columns[position]
print (colname)
# Out:
# tarw

# %% [markdown]
# ## Step 9. What is the type of the observations of the 2th column?

# %%
birds.huml.dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ## Step 10. How is the dataset indexed?
# - Indexing in pandas means simply selecting particular rows and columns of data from a DataFrame. Indexing could be selecting all the rows and some of the columns, some of the rows and all of the columns, or some of each of the rows and columns. Indexing can also be known as Subset Selection of a data frame.

# %%
birds.index
# Out:
# RangeIndex(start=0, stop=420, step=1)

# %%
birds[::-1] # reverse of the series
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
#
#     type
# 419   SO
# 418   SO
# 417   SO
# 416   SO
# 415   SO
# ...

# %%
birds[1::100] # indexing with a gap 100
# Out:
#       id    huml   humw   ulnal  ulnaw    feml   femw    tibl  tibw    tarl  \
# 1      1   88.91   6.63   80.53   5.59   47.04   4.30   80.22  4.51   41.50
# 101  101   67.59   3.73   68.55   3.19   24.46   1.89   50.06  2.36   27.21
# 201  201  118.75  11.90  104.68   4.77  108.85  10.29  183.00  9.69  134.00
# 301  301   21.07   2.00   25.36   1.70   17.66   1.72   26.28  1.35   19.43
# 401  401   21.53   1.91   25.30   1.67   20.80   1.65   34.08  1.33   23.86
#
#      tarw type
# 1    4.01   SW
# 101  1.77   SW
# 201  7.96    T
# 301  1.36   SO
# 401  1.27   SO

# %% [markdown]
# ## Step 11. Set the 'type' colum as the index of the dataframe

# %%
bird = birds.copy()
bird = bird.set_index('type')
bird
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# SW      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# SW      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# SW      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# SW      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# SW      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ...   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# SO    415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# SO    416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# SO    417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# SO    418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
# [420 rows x 11 columns]

# %% [markdown]
# ## Step 12. Print only the column huml

# %%
birds[["huml"]]
# Out:
#       huml
# 0    80.78
# 1    88.91
# 2    79.97
# 3    77.65
# 4    62.80
# ..     ...
# 415  17.96
# 416  19.21
# 417  18.79
# 418  20.38
# 419  17.89
#
# [420 rows x 1 columns]

# %% [markdown]
# ## Step 13. Print the "huml","humw" columns from SW and P

# %%
birds[(birds["type"]=="SW") | (birds["type"]=="P")]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 287  287  27.72  2.67  32.00   2.21  22.68  2.13  32.50  1.76  19.65  1.64
# 288  288  29.14  2.75  32.91   2.16  23.13  2.11  33.89  1.80  20.86  1.70
# 289  289  27.85  2.65  32.62   2.05  22.84  2.14  33.62  1.91  20.82  1.80
# 290  290  20.06  1.73  23.15   1.49  16.63  1.57  24.71  1.29  15.19  1.24
# 291  291  41.60  3.74  56.50   3.02  37.00  2.99  62.90  2.82  38.21  2.51
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %% [markdown]
# ## Step 14. Select the rows 3 to 7 and the columns 3 to 6

# %%
birds.iloc[3:7,3:6]
# Out:
#    ulnal  ulnaw   feml
# 3  65.76   4.77  40.04
# 4  52.09   3.73  33.95
# 5  50.46   3.47  49.52
# 6  67.39   4.50  42.07

# %% [markdown]
# ## Step 15. Select rows where df.femw is greater than 5.2 or less than 10.5

# %%
#Greater than 5.2
birds[birds["femw"] >5.2]
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 10    10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# 11    11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# 12    12  172.00   8.44  142.00   8.43  52.18  6.68  180.00  9.62  82.58
# ..   ...     ...    ...     ...    ...    ...   ...     ...   ...    ...
# 237  237  119.12   7.57  137.37   6.06  75.53  6.35  115.02  6.22  60.99
# 238  238  117.43   7.13  136.26   5.51  75.54  5.85  115.30  5.45  59.45
# 239  239  116.85   7.43  134.80   6.19  73.51  6.10  112.66  5.94  61.25
# 240  240  119.58   8.04  138.39   6.25  76.36  6.50  115.90  6.07  59.90
# 241  241  126.88   8.01  148.47   6.59  81.42  6.71  124.05  6.58  64.57
#
#      tarw type
# 8    4.37   SW
# 9    6.34   SW
# 10   6.63   SW
# 11   4.59   SW
# ...

# %%
#Less than 10.5
birds[birds["femw"] <10.5]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %% [markdown]
# ## Step 16. Select the third cell down in the column named tarl

# %%
birds.loc[3,"tarl"]
# Out:
# 35.78

# %% [markdown]
# ## Step 17. Compute how many values are non-missing for each feature over the entire record

# %%
birds.notnull().sum()
# Out:
# id       420
# huml     419
# humw     419
# ulnal    417
# ulnaw    418
# feml     418
# femw     419
# tibl     418
# tibw     419
# tarl     419
# tarw     419
# type     420
# dtype: int64

# %% [markdown]
# ## Step18. Calculate Mean and Median of "tibl" and "tibw" columns

# %%
birds_mean = birds[["tibl","tibw"]].mean()
birds_median = birds[["tibl","tibw"]].median()
print("The means are:", birds_mean)
print("The medians are:", birds_median)
# Out:
# The means are: tibl    64.662823
# tibw     3.182339
# dtype: float64
# The medians are: tibl    52.12
# tibw     2.49
# dtype: float64

# %% [markdown]
# ## Step19. Discover what is the mean "ulnaw" per every bird category

# %%
birds_mean = birds["ulnaw"].mean()
birds_mean
# Out:
# 3.5972488038277497

# %% [markdown]
# ## Step20. Plot graph between all features refuse "type" and "id" columns

# %%
birds.plot(x ='type', y='id', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='type'>

# %%
birds.plot(x ='type', y='id', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='type', ylabel='id'>

# %%
import matplotlib.pyplot as plt

plt.plot(birds["type"],birds["id"])
plt.show()
